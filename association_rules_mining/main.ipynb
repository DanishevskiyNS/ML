# %%
import pandas as pd
import numpy as np
import plotly.express as px
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules

# %%
from importlib import reload
from src import encode_transactions, association_rules_custom

# %% [markdown]
# Датасет `Market_Basket_Optimisation` [здесь](https://www.kaggle.com/datasets/devchauhan1/market-basket-optimisationcsv/data)

# %%
df = pd.read_csv('../data/market_basket_optimization/Market_Basket_Optimisation.csv')

# %%
df
# Out:
#               shrimp            almonds      avocado    vegetables mix  \
# 0            burgers          meatballs         eggs               NaN
# 1            chutney                NaN          NaN               NaN
# 2             turkey            avocado          NaN               NaN
# 3      mineral water               milk   energy bar  whole wheat rice
# 4     low fat yogurt                NaN          NaN               NaN
# ...              ...                ...          ...               ...
# 7495          butter         light mayo  fresh bread               NaN
# 7496         burgers  frozen vegetables         eggs      french fries
# 7497         chicken                NaN          NaN               NaN
# 7498        escalope          green tea          NaN               NaN
# 7499            eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#      green grapes whole weat flour yams cottage cheese energy drink  \
# ...

# %%
# get transactions in np.ndarray
transaction = df.values.astype(str)
encoded_transactions = encode_transactions(transaction, as_frame=True)
# Out:
# (120,)

# %%
dataframe = fpgrowth(encoded_transactions, min_support=0.05, use_colnames=True)

# %%
dataframe.head(10)
# Out:
#     support            itemsets
# 0  0.179733              (eggs)
# 1  0.087200           (burgers)
# 2  0.062533            (turkey)
# 3  0.238267     (mineral water)
# 4  0.132000         (green tea)
# 5  0.129600              (milk)
# 6  0.058533  (whole wheat rice)
# 7  0.076400    (low fat yogurt)
# 8  0.170933      (french fries)
# 9  0.050533              (soup)

# %%
association_rules_df = association_rules_custom(dataframe, 'lift', threshold=1)

# %%
association_rules_df
# Out:
#        antecedents      consequents  antecedent support  consequent support  \
# 0           (eggs)  (mineral water)            0.179733            0.238267
# 1  (mineral water)           (eggs)            0.238267            0.179733
# 2      (spaghetti)  (mineral water)            0.174133            0.238267
# 3  (mineral water)      (spaghetti)            0.238267            0.174133
# 4      (chocolate)  (mineral water)            0.163867            0.238267
# 5  (mineral water)      (chocolate)            0.238267            0.163867
#
#     support  confidence      lift  leverage  conviction  zhangs_metric
# 0  0.050933    0.283383  1.189351  0.008109    1.062957       0.194090
# 1  0.050933    0.213766  1.189351  0.008109    1.043286       0.209004
# 2  0.059733    0.343032  1.439698  0.018243    1.159468       0.369806
# 3  0.059733    0.250699  1.439698  0.018243    1.102184       0.400941
# 4  0.052667    0.321400  1.348907  0.013623    1.122506       0.309351
# ...
